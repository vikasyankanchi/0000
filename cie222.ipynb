# %% [markdown]
# <a href="https://colab.research.google.com/github/vikasyankanchi/0000/blob/main/cie222.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = sns.load_dataset('titanic')

df.info()

# %%
print(df.isnull().sum())

# %%
sum1=(df["survived"].isnull().sum())
sum2=(df["age"].isnull().sum())
print(sum1+sum2)

# %%
print(df["survived"].isnull().sum())
print(df["age"].isnull().sum())

# %%
sns.countplot(x="class",hue="pclass",data=df)
plt.title("passenger count by pclass")
plt.show()
