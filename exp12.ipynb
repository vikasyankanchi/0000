# %% [markdown]
# <a href="https://colab.research.google.com/github/vikasyankanchi/0000/blob/main/exp12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/cie_see.csv')
df
# Out:
#     Unnamed: 0      Reg No                           Name  Sem  CIE  SEE
# 0            0  393CS18001  ABHISHEK NEELKANTAPPA JAMBAGI    1  121  204
# 1            1  393CS18002                AISHWARYA PATIL    1  296  440
# 2            2  393CS18003     AKASH BASAVARAJ MALAPPAGOL    1  185  308
# 3            3  393CS18004   AKASH MUTTAPPA JANGAMASHETTI    1   94  154
# 4            4  393CS18005                 ANUSHREE PATIL    1   99  164
# 5            5  393CS18007                 CHAITRA PATTAR    1  390  531
# 6            6  393CS18008                CHETAN KAPPARAD    1  222  344
# 7            7  393CS18010             MALLIKARJUN KORWAR    1  155  267
# 8            8  393CS18012            MRUTUNJAY GUDDODAGI    1  193  299
# 9            9  393CS18013             NADAF SOHAIL NASIM    1  340  484
# 10          10  393CS18014             NIKIL NADUVINAKERI    1   30   54
# 11          11  393CS18015            PATIL AMRUTA ARVIND    1  306  450
# ...

# %%
x =	df[['CIE']]
x
# Out:
#     CIE
# 0   121
# 1   296
# 2   185
# 3    94
# 4    99
# 5   390
# 6   222
# 7   155
# 8   193
# 9   340
# 10   30
# 11  306
# 12  228
# 13  100
# 14  138
# 15  180
# 16   66
# 17  118
# 18  103
# 19  105
# 20  280
# 21  192
# 22  245
# 23  276
# 24  377
# 25  104
# 26  200

# %%
y =	df[['SEE']]
y
# Out:
#     SEE
# 0   204
# 1   440
# 2   308
# 3   154
# 4   164
# 5   531
# 6   344
# 7   267
# 8   299
# 9   484
# 10   54
# 11  450
# 12  341
# 13  172
# 14  243
# 15  304
# 16  130
# 17  227
# 18  177
# 19  182
# 20  411
# 21  298
# 22  380
# 23  420
# 24  522
# 25  180
# 26  327

# %%
sns.scatterplot(data=df,x=df['CIE'],y=df['SEE'])
# Out:
# <Axes: xlabel='CIE', ylabel='SEE'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['CIE']],df[["SEE"]],test_size=0.2)

# %%
x_train
# Out:
#     CIE
# 22  245
# 21  192
# 24  377
# 19  105
# 8   193
# 4    99
# 1   296
# 13  100
# 2   185
# 7   155
# 14  138
# 15  180
# 18  103
# 3    94
# 12  228
# 0   121
# 17  118
# 5   390
# 9   340
# 10   30
# 25  104

# %%
x_test
# Out:
#     CIE
# 20  280
# 6   222
# 11  306
# 23  276
# 26  200
# 16   66

# %%
y_train
# Out:
#     SEE
# 22  380
# 21  298
# 24  522
# 19  182
# 8   299
# 4   164
# 1   440
# 13  172
# 2   308
# 7   267
# 14  243
# 15  304
# 18  177
# 3   154
# 12  341
# 0   204
# 17  227
# 5   531
# 9   484
# 10   54
# 25  180

# %%
y_test
# Out:
#     SEE
# 20  411
# 6   344
# 11  450
# 23  420
# 26  327
# 16  130

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
x_pred=lr.predict(x_train)
print("x_pred",x_pred)
print("y_pred",y_pred)
# Out:
# x_pred [[365.65178193]
#  [297.14036678]
#  [536.28398571]
#  [184.67823246]
#  [298.43303499]
#  [176.9222232 ]
#  [431.57786067]
#  [178.21489141]
#  [288.0916893 ]
#  [249.31164299]
#  [227.33628341]
#  [281.62834825]
#  [182.09289604]
#  [170.45888215]
#  [343.67642235]
#  [205.36092383]
#  [201.4829192 ]
#  [553.08867245]
#  [488.45526193]
#  [ 87.72811668]
#  [183.38556425]]
# y_pred [[410.8951693 ]
#  [335.92041309]
#  [444.50454277]
#  [405.72449646]
#  [307.48171246]
#  [134.26417226]]

# %%
y_test
# Out:
#     SEE
# 20  411
# 6   344
# 11  450
# 23  420
# 26  327
# 16  130

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
r2 = r2_score(y_test , y_pred)

# %%
import numpy as np
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(10.789095414650234)

# %%
print ("Mean Squared Error",mse)
print("Mean Absolute Error",mae)
print("R2_Score",r2)
# Out:
# Mean Squared Error 116.40457986642672
# Mean Absolute Error 8.622973029964385
# R2_Score 0.9896578291891465

# %%
plt.scatter(x_train, y_train, color="green")
plt.plot(x_train, x_pred, color="red")
plt.title("CIE vs SEE (Training Dataset)")
plt.xlabel("CIE")
plt.ylabel("SEE")
plt.show()
