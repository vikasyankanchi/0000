# %% [markdown]
# <a href="https://colab.research.google.com/github/vikasyankanchi/0000/blob/main/cieee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df =sns.load_dataset('titanic')
print(df.info)
print("age",df["age"].describe())
print("fare",df["fare"].describe())
print(df.head(10))

# %%
df.info()

# %%
print(df["age"].describe())

# %%
df.info

# %%
print(df.head(10))

# %%
print(df.head(10))
df["survived"]=df["survived"].replace({0:"not survived",1:"survived"})
print(df.head(10))

# %%
sns.countplot(x="pclass",hue="survived",data=df)
plt.title(" survival count by passanger class ")
plt.show()

# %%
print(df.isnull().sum())

# %%
df["age"]=df["age"].fillna(df["age"].mean())

print(df.isnull().sum())

# %%
from scipy.stats import zscore
df['age'] = zscore (df['age'].fillna(df['age'].mean()))
df['fare'] = zscore(df [ 'fare'].fillna(df['fare'].mean()))
outliers = df [(abs(df['age']) > 3) | (abs(df['fare']) > 3)]
print("Detected Outliers:\n", outliers [['age', 'fare']])
sns.boxplot(x=df['age'])
plt.title("age Outliers")
plt.show()
sns.boxplot(x=df['fare'])
plt.title("fare Outliers")
plt.show()
